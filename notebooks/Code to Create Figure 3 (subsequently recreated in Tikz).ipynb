# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
def dToR(degrees):
    return degrees/180. * np.pi

# %%
theta = np.linspace(35,55,10)
z = np.linspace(-1,1,10)

thv, zv = np.meshgrid(theta,z)

# %%
def compute_xyz(thetas, zs):
    rv = 10 +(zs+1)*(zs-1)*np.sin(dToR(thetas * 15+60))

    xv = rv * np.cos(dToR(thetas))
    zv = rv * np.sin(dToR(thetas))
    yv = zs
    return(xv,yv,zv)

# %%
xv,yv,zv = compute_xyz(thv,zv)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter(xv,yv,zv)
#ax.set_xlim(-8,-12)
#ax.set_zlim(-2,2)
#ax.set_ylim(-2,2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
55-15*0.4
# Out:
# 49.0

# %%
pointOfEvaluation = np.array((5.78509,0.,6.8944))
center = np.array((6.07022,-1.67132*10**-16,7.23421))
radius = 0.443588
v1 = np.array((0.473161,0.786439,-0.397029))
v2 = np.array((0.642788,-3.76774*10**-16,0.766044))
print(np.sum(v1**2), np.sum(v2**2), np.sum(v1*v2))
# Out:
# 0.9999996594830001 0.99999982288 5.295919997538867e-07

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_box_aspect([1,1,1])
ax.scatter(xv,yv,zv)
ax.scatter(pointOfEvaluation[0],pointOfEvaluation[1],pointOfEvaluation[2],color="red")
thetas = np.linspace(0,2 * np.pi, 100)
pts = [radius * (v1 * np.cos(th) + v2 * np.sin(th)) + center for th in thetas]
pts = np.array(pts)

ax.scatter(pts[:,0],pts[:,1],pts[:,2],color="black")
ax.set_xlim(5,9)
ax.set_ylim(-2,2)
ax.set_zlim(5,9)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (5.0, 9.0)

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.3.1'

# %%
pointOfEvaluation = np.array(({6.21992,0.,6.78785}))
center = np.array((6.46897, -0.488867, 7.77863))
radius = 1.13254
v1 = np.array((0.86092, 0.5076, 0.0340509))
v2 = np.array((0.219903, -0.431655, 0.874824))
print(np.sum(v1**2), np.sum(v2**2), np.sum(v1*v2))
# Out:
# 1.00000047019081 1.0000003994100002 -6.426984000378055e-07
