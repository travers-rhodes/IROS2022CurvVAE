# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-6c0n375h because the default path (/home/tsr42/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
def dToR(degrees):
    return degrees/180. * np.pi

# %%
theta = np.linspace(35,55,10)
z = np.linspace(-1,1,10)

thv, zv = np.meshgrid(theta,z)

# %%
def compute_xyz(thetas, zs):
    rv = 10 +(zs+1)*(zs-1)*np.sin(dToR(thetas * 15+60))

    xv = rv * np.cos(dToR(thetas))
    zv = rv * np.sin(dToR(thetas))
    yv = zs
    return(xv,yv,zv)

# %%
xv,yv,zv = compute_xyz(thv,zv)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter(xv,yv,zv)
#ax.set_xlim(-8,-12)
#ax.set_zlim(-2,2)
#ax.set_ylim(-2,2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
55-15*0.4
# Out:
# 49.0

# %%
th_inter = 55
z_inter= -1

xint,yint,zint = compute_xyz(th_inter, z_inter)

# %%
pointOfEvaluation = np.array((5.95223, -0.2, 6.84726))
center = np.array((6.21285, -0.218666, 7.17789))
radius = 0.421409
v1 = np.array((0.618875, 0.642727, -0.451547))
v2 = np.array((0.618448, -0.0442945, 0.784576))
print(np.sum(v1**2), np.sum(v2**2), np.sum(v1*v2))
# Out:
# 0.999998955363 0.99999943121025 -2.0417350005130785e-07

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_aspect('equal')
ax.scatter(xv,yv,zv)
ax.scatter(pointOfEvaluation[0],pointOfEvaluation[1],pointOfEvaluation[2],color="red")
thetas = np.linspace(0,2 * np.pi, 100)
pts = [radius * (v1 * np.cos(th) + v2 * np.sin(th)) + center for th in thetas]
pts = np.array(pts)

ax.scatter(pts[:,0],pts[:,1],pts[:,2],color="black")
ax.set_xlim(5,9)
ax.set_ylim(-2,2)
ax.set_zlim(5,9)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-16-ff9c23fcad70> in <module>
#       1 fig = plt.figure()
#       2 ax = plt.axes(projection='3d')
# ----> 3 ax.set_aspect('equal')
#       4 ax.scatter(xv,yv,zv)
#       5 ax.scatter(pointOfEvaluation[0],pointOfEvaluation[1],pointOfEvaluation[2],color="red")
#
# ~/anaconda3/envs/curvvae/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in set_aspect(self, aspect, adjustable, anchor, share)
#     322         if aspect != 'auto':
#     323             raise NotImplementedError(
# --> 324                 "Axes3D currently only supports the aspect argument "
#     325                 f"'auto'. You passed in {aspect!r}."
#     326             )
#
# NotImplementedError: Axes3D currently only supports the aspect argument 'auto'. You passed in 'equal'.
